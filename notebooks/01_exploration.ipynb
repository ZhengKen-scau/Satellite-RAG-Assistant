# %% [markdown]
# # Satellite RAG Assistant - 数据探索
#
# 卫星遥感RAG助手 - 数据探索笔记本
#
# 本笔记本用于探索和分析原始卫星遥感数据。

# %%
# 导入必要的库
import os
import pandas as pd
import numpy as np
from pathlib import Path

# 设置项目根目录
project_root = Path('../')
data_dir = project_root / 'data' / 'raw'

print(f"项目根目录: {project_root}")
print(f"数据目录: {data_dir}")

# %%
# 列出原始数据文件
if data_dir.exists():
    files = list(data_dir.glob('*'))
    print(f"找到 {len(files)} 个文件:")
    for file in files:
        print(f"  - {file.name}")
else:
    print("数据目录不存在")

# %%
# TODO: 添加具体的数据探索代码
# 例如：PDF文档解析、文本提取、统计分析等
print("数据探索完成！")
